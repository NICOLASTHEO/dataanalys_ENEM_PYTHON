# %% [markdown]
# # ANÁLISE DOS MICRODADOS ENEM - 2021

# %%
import pandas as pd
import matplotlib

# %%
microdadosEnem2021 = pd.read_csv("C:/Users/NewUser/Desktop/Private Theo/BI Theo/Python/Projeto2/microdados_enem_2021/DADOS/MICRODADOS_ENEM_2021.csv", sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem2021.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdadosEnem2021
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# # NOTA-SE QUE O ENEM DE 2021 TEVE 3.389.832 INSCRITOS

# %%
microdadosEnem2021.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadosENEM = ['TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'TP_LINGUA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO']

# %% [markdown]
# ## SELECIONADAS AS COLUNAS QUE QUERO TRABALHAR, CONFIRMO O FILTRO

# %%
microdadosEnem2021Selecionados = microdadosEnem2021.filter(items=colunasSelecionadosENEM)

# %%
microdadosEnem2021Selecionados.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  \
# 0                5       F                1            1                 1
# 1               12       M                1            1                 1
# 2               13       F                3            1                 1
# 3                3       M                1            3                 1
# 4                2       F                1            3                 1
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  ...  \
# 0                1                3          1        NaN             0  ...
# 1                1               11          1        NaN             0  ...
# 2                1               15          1        NaN             0  ...
# 3                2                0          2        1.0             0  ...
# 4                2                0          2        1.0             0  ...
#
# ...

# %%
enem1MiMicrodadosEnem2021 = microdadosEnem2021Selecionados[0:1000000] # VISUALIZAR E TRABALHAR COM POUCAS LINHAS.

# %%
enem1MiMicrodadosEnem2021
# Out:
#         TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0                     5       F                1            1
# 1                    12       M                1            1
# 2                    13       F                3            1
# 3                     3       M                1            3
# 4                     2       F                1            3
# ...                 ...     ...              ...          ...
# 999995                2       F                1            5
# 999996                5       F                1            3
# 999997                5       F                1            0
# 999998                4       F                1            1
# 999999                2       F                1            3
#
#         TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0                      1                1                3          1
# 1                      1                1               11          1
# ...

# %% [markdown]
# ## VERIFICAR O TOTAL DE INSCRITOS POR MUNICIPIO

# %%
coluna_mun_prova = microdadosEnem2021Selecionados['NO_MUNICIPIO_PROVA']

# %%
coluna_mun_prova
# Out:
# 0                      Nova Lima
# 1                         Maceió
# 2          Ferraz de Vasconcelos
# 3                          Crato
# 4                        Acarape
#                    ...
# 3389827                  Goiânia
# 3389828                 Londrina
# 3389829           Rio de Janeiro
# 3389830             Pouso Alegre
# 3389831                  Baraúna
# Name: NO_MUNICIPIO_PROVA, Length: 3389832, dtype: object

# %% [markdown]
# ## AGRUPAR OS MUNICIPIOS E ORDENAR

# %%
mun_provas_unicos = coluna_mun_prova.value_counts().sort_index()

# %%
mun_provas_unicos
# Out:
# Abaetetuba               5198
# Abaeté                    677
# Abreu e Lima             2078
# Acarape                   437
# Acaraú                   1303
#                          ...
# Água Preta                257
# Águas Belas               888
# Águas Formosas            380
# Águas Lindas de Goiás    2746
# Óbidos                    771
# Name: NO_MUNICIPIO_PROVA, Length: 1712, dtype: int64

# %% [markdown]
# ## VERIFICAR A FAIXA ETÁRIA DOS INSCRITOS

# %%
coluna_idade=microdadosEnem2021Selecionados['TP_FAIXA_ETARIA']

# %%
coluna_idade.head()
# Out:
# 0     5
# 1    12
# 2    13
# 3     3
# 4     2
# Name: TP_FAIXA_ETARIA, dtype: int64

# %% [markdown]
# ## ORDENAR E AGRUPAR AS FAIXAS ETÁRIAS (ESTÃO POR ID)

# %%
coluna_idade.value_counts().sort_index()
# Out:
# 1     274318
# 2     620784
# 3     699365
# 4     394689
# 5     250690
# 6     177086
# 7     132052
# 8     100580
# 9      85742
# 10     71199
# 11    227574
# 12    130746
# 13     93073
# 14     58754
# 15     35808
# 16     20564
# 17     10804
# 18      4102
# 19      1342
# 20       560
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
coluna_idade.hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ELABORADO UM GRÁFICO HISTOGRAMA

# %% [markdown]
# # VERIFICAÇÃO DAS UF DE REALIZAÇÃO DE PROVAS POR INSCRITOS

# %%
coluna_ESTADO = microdadosEnem2021Selecionados['SG_UF_PROVA']

# %%
coluna_ESTADO
# Out:
# 0          MG
# 1          AL
# 2          SP
# 3          CE
# 4          CE
#            ..
# 3389827    GO
# 3389828    PR
# 3389829    RJ
# 3389830    MG
# 3389831    RN
# Name: SG_UF_PROVA, Length: 3389832, dtype: object

# %% [markdown]
# ## ORDENAR E AGRUPAR ESTADOS, VÊ-SE QUE EM SP TEM-SE MAIS INSCRITOS

# %%
coluna_ESTADO.value_counts()
# Out:
# SP    509954
# MG    327829
# BA    266194
# RJ    238347
# CE    220517
# PE    193616
# PA    185978
# RS    150484
# PR    144282
# GO    136915
# MA    127905
# PB    102002
# AM     89778
# RN     80820
# SC     80765
# PI     79969
# DF     67501
# ES     64181
# AL     56584
# MT     56085
# SE     53796
# MS     42490
# RO     32801
# TO     30873
# AP     21774
# AC     20336
# RR      8056
# Name: SG_UF_PROVA, dtype: int64

# %% [markdown]
# ## HISTOGRAMA DE INSCRITOS POR ESTADO - MEDIDA DE 40 para view

# %%
coluna_ESTADO.hist(bins=40)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## VERIFICAÇÃO DE RELAÇÃO POR SEXO, M / F

# %%
coluna_sexo = microdadosEnem2021Selecionados['TP_SEXO']

# %%
coluna_sexo
# Out:
# 0          F
# 1          M
# 2          F
# 3          M
# 4          F
#           ..
# 3389827    F
# 3389828    F
# 3389829    F
# 3389830    F
# 3389831    F
# Name: TP_SEXO, Length: 3389832, dtype: object

# %%
disntsexo = coluna_sexo.value_counts()

# %% [markdown]
# ## AGRUPA E ORDENA O TOTAL DE CANDIDATOS POR SEXO

# %%
disntsexo
# Out:
# F    2090526
# M    1299306
# Name: TP_SEXO, dtype: int64

# %% [markdown]
# ### PERCENTUAL DE INSCRITOS POR SEXO:

# %%
percent_sexo = [100*i/disntsexo.sum() for i in disntsexo]

# %%
percent_sexo
# Out:
# [61.67048986498446, 38.32951013501554]

# %% [markdown]
# ### TIPO DE ESCOLA POR CANDIDATOS, PUBL / PRIV / OUTRO

# %%
coluna_tip_esc = microdadosEnem2021Selecionados['TP_ESCOLA']

# %%
coluna_tip_esc
# Out:
# 0          1
# 1          1
# 2          1
# 3          2
# 4          2
#           ..
# 3389827    1
# 3389828    1
# 3389829    1
# 3389830    1
# 3389831    1
# Name: TP_ESCOLA, Length: 3389832, dtype: int64

# %%
disnt_esc = coluna_tip_esc.value_counts()

# %% [markdown]
# ### AGRUPA E ORDENA TOTAL DOS TIPOS DE ESCOLAS DOS CANDIDATOS

# %%
disnt_esc
# Out:
# 1    2238977
# 2     958611
# 3     192244
# Name: TP_ESCOLA, dtype: int64

# %% [markdown]
# # FIM DA PRIMEIRA ANÁLISE BÁSICA EM PYTHON
